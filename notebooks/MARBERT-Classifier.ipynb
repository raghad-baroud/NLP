# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
import torch
from transformers import AutoTokenizer, AutoModelForSequenceClassification, AdamW,BertTokenizerFast,Trainer, TrainingArguments
from transformers import AutoTokenizer, AutoModelForSequenceClassification, AdamW
from matplotlib import pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay, classification_report, accuracy_score

# %%
#matplotlib style to the standard style
plt.style.use('default')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Read and clean data

# %%
training_data = pd.read_csv("/content/drive/MyDrive/SeniorProject1/data/experiment/SP2_new_training_set.csv")

# %%
test = pd.read_csv("/content/drive/MyDrive/SeniorProject1/data/experiment/SP2_new_testing_set.csv")
test.shape
# Out:
# (750, 4)

# %%
training_data.isnull().sum()
# Out:
# Unnamed: 0    0
# Tweet         9
# Class         0
# dtype: int64

# %%
training_data.dropna(inplace=True)
training_data.isnull().sum()
# Out:
# Unnamed: 0    0
# Tweet         0
# Class         0
# dtype: int64

# %%
train,val = train_test_split(training_data,test_size=0.15, random_state=42)

# %%
len(train), len(val)
# Out:
# (6367, 1124)

# %%
train['Class'].value_counts()
# Out:
# Class
# neutral     2155
# positive    2121
# negative    2091
# Name: count, dtype: int64

# %% [markdown]
# ## Prepare Data and model

# %%
train['Class']=train['Class'].map({'negative': 0,'neutral': 1, 'positive': 2})
val['Class'] = val['Class'].map({'negative': 0,'neutral': 1, 'positive': 2})
test['Class'] = test['Class'].map({'negative': 0,'neutral': 1, 'positive': 2})

# %%
model = AutoModelForSequenceClassification.from_pretrained('UBC-NLP/MARBERT', num_labels=len(train['Class'].unique()))
tokenizer = BertTokenizerFast.from_pretrained('UBC-NLP/MARBERT')
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at UBC-NLP/MARBERT and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %% [markdown]
# ### Encode text & prepare dataloader

# %%
train_encodings = tokenizer(train['Tweet'].to_list(), truncation=True, padding=True, max_length=44)
val_encodings = tokenizer(val['Tweet'].to_list(), truncation=True, padding=True, max_length=44)
test_encodings = tokenizer(test["Tweet"].tolist(), truncation=True, padding=True,max_length=44)

# %%
train_labels = train['Class']
val_labels = val['Class']
test_labels = test['Class']

# %%
class SentimentDataset(Dataset):
  def __init__(self, encodings, labels):
      self.encodings = encodings
      self.labels = labels.to_list()

  def __getitem__(self, idx):
      item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
      item['labels'] = torch.tensor(self.labels[idx]).long()
      return item

  def __len__(self):
      return len(self.labels)

# %%
ds_train = SentimentDataset(train_encodings, train_labels)
ds_val =  SentimentDataset(val_encodings, val_labels)
ds_test =  SentimentDataset(test_encodings, test_labels)

# %% [markdown]
# ### Training Arguments

# %%
def compute_metrics(eval_pred):
  logits, labels = eval_pred
  predictions = np.argmax(logits, axis=-1)
  acc = accuracy_score(labels, predictions)
  return {
      'accuracy': acc,
  }

# %%
training_args = TrainingArguments(
    output_dir='/marbert-checkpoints',
    num_train_epochs=2,
    per_device_train_batch_size=64,
    per_device_eval_batch_size=32,
    eval_strategy = "epoch",
    save_strategy = 'epoch',
    )
for param in model.parameters():
   param.data = param.data.contiguous()

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=ds_train,
    eval_dataset=ds_val,
    compute_metrics=compute_metrics
)

# %% [markdown]
# ## Training

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='200' max='200' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [200/200 03:33, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.949354</td>
#       <td>0.849644</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.931144</td>
#       <td>0.859431</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=200, training_loss=0.035710315704345706, metrics={'train_runtime': 214.4523, 'train_samples_per_second': 59.379, 'train_steps_per_second': 0.933, 'total_flos': 287932413084624.0, 'train_loss': 0.035710315704345706, 'epoch': 2.0})

# %% [markdown]
# ## Testing

# %%
preds = trainer.predict(ds_test)

# %%
y_pred = [np.argmax(i, axis=-1) for i  in preds.predictions]
y_test = ds_test.labels

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.748

# %%
model_name='MARBERT Classifier'
print(classification_report(y_test, y_pred,target_names=['negative','neutral','positive']))
fig,ax=plt.subplots(figsize=(5, 5))
ConfusionMatrixDisplay.from_predictions(y_test, y_pred,display_labels=['negative','neutral','positive'],normalize='pred',cmap=plt.cm.Blues, xticks_rotation='vertical',ax=ax)
plt.title(f'Confusion Matrix of {model_name}')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#     negative       0.90      0.68      0.77       250
#      neutral       0.70      0.74      0.72       250
#     positive       0.69      0.83      0.75       250
#
#     accuracy                           0.75       750
#    macro avg       0.76      0.75      0.75       750
# weighted avg       0.76      0.75      0.75       750

# %% [markdown]
# # New

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='200' max='200' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [200/200 03:25, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.382664</td>
#       <td>0.846975</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.360374</td>
#       <td>0.870107</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=200, training_loss=0.39969200134277344, metrics={'train_runtime': 205.725, 'train_samples_per_second': 61.898, 'train_steps_per_second': 0.972, 'total_flos': 287932413084624.0, 'train_loss': 0.39969200134277344, 'epoch': 2.0})

# %%
preds = trainer.predict(ds_test)
y_pred = [np.argmax(i, axis=-1) for i  in preds.predictions]
y_test = ds_test.labels
accuracy_score(y_test, y_pred)
# Out:
# 0.748

# %%
model_name='MARBERT Classifier'
print(classification_report(y_test, y_pred,target_names=['negative','neutral','positive']))
fig,ax=plt.subplots(figsize=(5, 5))
ConfusionMatrixDisplay.from_predictions(y_test, y_pred,display_labels=['negative','neutral','positive'],normalize='pred',cmap=plt.cm.Blues, xticks_rotation='vertical',ax=ax)
plt.title(f'Confusion Matrix of {model_name}')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#     negative       0.87      0.66      0.75       250
#      neutral       0.67      0.79      0.72       250
#     positive       0.75      0.80      0.78       250
#
#     accuracy                           0.75       750
#    macro avg       0.76      0.75      0.75       750
# weighted avg       0.76      0.75      0.75       750

# %%
trainer.save_model("/content/drive/MyDrive/SeniorProject1/models/MARBERT-Classifier")
